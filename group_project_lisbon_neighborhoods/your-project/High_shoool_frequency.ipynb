# %% [markdown]
# # HIGH SCHOOL

# %%
import pandas as pd
import numpy as np

# %%
high_s = pd.read_csv('high_schooll_original.csv')
high_s
# Out:
#            X          Y                                           INF_NOME  \
# 0  -9.156713  38.726502        Escola Secundária Maria Amália Vaz Carvalho
# 1  -9.162225  38.741987                       Escola Secundária D. Pedro V
# 2  -9.194106  38.747471              Escola Secundária José Gomes Ferreira
# 3  -9.180852  38.761523                Escola Secundária Vergílio Ferreira
# 4  -9.130925  38.726555               Escola Secundária D. Luísa de Gusmão
# 5  -9.140165  38.739727  Escola Básica e Secundária D. Filipa de Lencastre
# 6  -9.141340  38.751355                 Escola Secundária Rainha D. Leonor
# 7  -9.128020  38.716470             Escola Básica e Secundária Gil Vicente
# 8  -9.214060  38.709707                          Escola Secundária Restelo
# 9  -9.188835  38.702386                 Escola Secundária Rainha D. Amélia
# 10 -9.188835  38.702386                Escola Secundária Fonseca Benevides
# 11 -9.158474  38.716418                      Escola Secundária Pedro Nunes
# 12 -9.143313  38.730170                           Escola Secundária Camões
# 13 -9.149872  38.711898           Escola Básica e Secundária Passos Manuel
# 14 -9.195595  38.699953                Escola Secundária Marquês de Pombal
# 15 -9.113011  38.751872                Escola Secundária D. Dinis - Lisboa
# 16 -9.108431  38.770312                  Escola Secundária António Damásio
# 17 -9.167566  38.713154        Escola Básica e Secundária Josefa de Óbidos
# 18 -9.135626  38.757744             Escola Secundária Padre António Vieira
# 19 -9.162269  38.769364                           Escola Secundária Lumiar
# 20 -9.112411  38.764592                   Escola Secundária Eça de Queirós
#
#                                         INF_DESCRICAO  \
# 0   Cursos nas Áreas CIENTÍFICO-HUMANÍSTICAS:  \nC...
# 1   Cursos nas Áreas CIENTÍFICO-HUMANÍSTICAS:  \nC...
# 2   Cursos nas Áreas CIENTÍFICO-HUMANÍSTICAS:  \nC...
# 3   Cursos nas Áreas CIENTÍFICO-HUMANÍSTICAS:  \nC...
# 4   Cursos nas Áreas CIENTÍFICO-HUMANÍSTICAS:  \nC...
# 5   Cursos nas Áreas CIENTÍFICO-HUMANÍSTICAS: \nCi...
# 6   Cursos nas Áreas CIENTÍFICO-HUMANÍSTICAS:  \nC...
# 7   Cursos nas Áreas CIENTÍFICO-HUMANÍSTICAS:  \nC...
# 8   Cursos nas Áreas CIENTÍFICO-HUMANÍSTICAS:  \nC...
# 9   Cursos nas Áreas CIENTÍFICO-HUMANÍSTICAS:  \nC...
# 10  Cursos nas Áreas CIENTÍFICO-HUMANÍSTICAS:  \nC...
# 11  Cursos nas Áreas CIENTÍFICO-HUMANÍSTICAS:  \nC...
# 12  Cursos nas Áreas CIENTÍFICO-HUMANÍSTICAS:  \nC...
# 13  Cursos nas Áreas CIENTÍFICO-HUMANÍSTICAS:  \nC...
# 14  Cursos nas Áreas CIENTÍFICO-HUMANÍSTICAS:  \nC...
# 15  Cursos nas Áreas CIENTÍFICO-HUMANÍSTICAS:  \nC...
# 16  Cursos nas Áreas CIENTÍFICO-HUMANÍSTICAS:  \nC...
# 17  Cursos nas Áreas CIENTÍFICO-HUMANÍSTICAS:\nCiê...
# 18  Cursos nas Áreas CIENTÍFICO-HUMANÍSTICAS:  \nC...
# 19  Cursos nas Áreas CIENTÍFICO-HUMANÍSTICAS:  \nC...
# 20  Cursos nas Áreas CIENTÍFICO-HUMANÍSTICAS:  \nC...
#
#                                               MORADA1               FREGUESIA
# 0   ['Escola Secundária Maria Amália Vaz de Carval...               Campolide
# 1   ['Escola Secundária Dom Pedro V', ' Estrada da...          Avenidas Novas
# 2   ['Escola Secundária José Gomes Ferreira', ' Ru...                 Benfica
# 3   ['Escola Secundária Vergílio Ferreira', ' Rua ...                 Carnide
# 4   ['Escola Secundária Dona Luisa de Gusmão', ' 1...                 Arroios
# 5   ['Escola Secundária Dona Filipa de Lencastre',...                 Areeiro
# 6   ['Escola Secundária Rainha Dona Leonor', ' Rua...                Alvalade
# 7   ['Escola Secundária Gil Vicente', ' Campo de S...             São Vicente
# 8   ['Escola Secundária do Restelo', ' Avenida das...                   Belém
# 9   ['Escola Secundária Rainha Dona Amélia', ' Rua...               Alcântara
# 10  ['Escola Secundária Rainha Dona Amélia', ' Rua...               Alcântara
# 11  ['Liceu Pedro Nunes', ' Rua Saraiva de Carvalh...        Campo de Ourique
# 12  ['Escola Secundária Luís de Camões', ' Rua Alm...                 Arroios
# 13  ['Escola Básica e Secundária Passos Manuel', '...            Misericórdia
# 14  ['Colégio Nuno Álvares - Casa Pia', ' 26', ' R...                   Belém
# 15  ['Escola Secundária Dom Dinis', ' Rua Luiz Pac...                 Marvila
# 16  ['Escola Secundária António Damásio', ' Rua Co...  Santa Maria de Olivais
# 17  ['Escola Josefa de Óbidos', ' Rua Professor Go...        Campo de Ourique
# 18  ['Escola Secundária Padre António Vieira', ' R...                Alvalade
# 19  ['Escola Secundária do Lumiar', ' Rua Mário Sa...                  Lumiar
# 20  ['Escola Secundária Eça de Queirós', ' Rua Cid...  Santa Maria de Olivais

# %%
high_s=high_s[['FREGUESIA','MORADA1']]

# %%
high_s_final=(high_s.groupby(['FREGUESIA'],as_index=False).count()).rename(columns={"MORADA1": "Frequency_High_School"})

# %%
high_s_final
# Out:
#                  FREGUESIA  Frequency_High_School
# 0                Alcântara                      2
# 1                 Alvalade                      2
# 2                  Areeiro                      1
# 3                  Arroios                      2
# 4           Avenidas Novas                      1
# 5                    Belém                      2
# 6                  Benfica                      1
# 7         Campo de Ourique                      2
# 8                Campolide                      1
# 9                  Carnide                      1
# 10                  Lumiar                      1
# 11                 Marvila                      1
# 12            Misericórdia                      1
# 13  Santa Maria de Olivais                      2
# 14             São Vicente                      1

# %%
high_s_final.to_csv('high_s.csv')
