# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # NO_EMPLOY BASE

# %%
no_employ = pd.read_csv('unemployment.csv')

# %%
no_employ = no_employ.rename(columns={'freguesia':'FREGUESIA','women_man': 'Total_Unemployed',
                                      'man': 'Man_Unemployed', 'women': 'Woman_Unemployed' })
no_employ

no_employ['FREGUESIA'] = [x.rstrip() for x in list(no_employ['FREGUESIA'])] #formating colum freguesia

# %%
no_employ
# Out:
#                   FREGUESIA  Total_Unemployed  Man_Unemployed  \
# 0                     Ajuda             15.54           17.71
# 1                 Alcântara             11.39           12.71
# 2                  Alvalade              9.52            9.90
# 3                   Areeiro              9.58           10.81
# 4                   Arroios             12.23           13.98
# 5            Avenidas Novas              9.16            9.75
# 6                     Beato             16.57           18.42
# 7                     Belém              8.42            8.95
# 8                   Benfica             13.36           14.97
# 9          Campo de Ourique             10.73           11.61
# 10                Campolide             12.56           14.12
# 11                  Carnide             12.39           14.54
# 12                  Estrela             10.35           11.24
# 13                   Lumiar              8.01            8.56
# ...

# %% [markdown]
# # CYCLO

# %%
cycl = pd.read_csv('Cyclo_frequency.csv')
cycl = cycl.drop(columns = 'Unnamed: 0')
#cycl = cycl[['FREGUESIA','Frequency_Cyclo']]

# %%
cycl = cycl.rename(columns={'Frequency_Cyclo':'f_Bike_Lanes'})

# %%
cycl
# Out:
#                   FREGUESIA  f_Bike_Lanes
# 0                     Ajuda             8
# 1                 Alcântara            11
# 2                  Alvalade            49
# 3                   Areeiro            41
# 4                   Arroios            15
# 5            Avenidas Novas           124
# 6                     Beato             1
# 7                     Belém            18
# 8                   Benfica            34
# 9          Campo de Ourique             1
# 10                Campolide            21
# 11                  Carnide            51
# 12                  Estrela             4
# 13                   Lumiar            33
# 14                  Marvila            26
# 15             Misericórdia             4
# 16                  Olivais            22
# 17        Parque das Nações           108
# 18          Penha de França             1
# 19              Santa Clara             6
# 20        Santa Maria Maior             8
# ...

# %% [markdown]
# # HIGH SCHOOL

# %%
##DONE

h_shool = pd.read_csv('high_s.csv')
h_shool = h_shool.drop(columns = 'Unnamed: 0')
h_shool
# Out:
#                  FREGUESIA  Frequency_High_School
# 0                Alcântara                      2
# 1                 Alvalade                      2
# 2                  Areeiro                      1
# 3                  Arroios                      2
# 4           Avenidas Novas                      1
# 5                    Belém                      2
# 6                  Benfica                      1
# 7         Campo de Ourique                      2
# 8                Campolide                      1
# 9                  Carnide                      1
# 10                  Lumiar                      1
# 11                 Marvila                      1
# 12            Misericórdia                      1
# 13  Santa Maria de Olivais                      2
# 14             São Vicente                      1

# %%
h_shool = h_shool.rename(columns={'Frequency_High_School':'f_High_School'})
h_shool
# Out:
#                  FREGUESIA  f_High_School
# 0                Alcântara              2
# 1                 Alvalade              2
# 2                  Areeiro              1
# 3                  Arroios              2
# 4           Avenidas Novas              1
# 5                    Belém              2
# 6                  Benfica              1
# 7         Campo de Ourique              2
# 8                Campolide              1
# 9                  Carnide              1
# 10                  Lumiar              1
# 11                 Marvila              1
# 12            Misericórdia              1
# 13  Santa Maria de Olivais              2
# 14             São Vicente              1

# %%
#DROP THE UNNAMED COLUMN
#h_shool = h_shool.drop(columns = 'Unnamed: 0')

# %%
h_shool
# Out:
#                  FREGUESIA  f_High_School
# 0                Alcântara              2
# 1                 Alvalade              2
# 2                  Areeiro              1
# 3                  Arroios              2
# 4           Avenidas Novas              1
# 5                    Belém              2
# 6                  Benfica              1
# 7         Campo de Ourique              2
# 8                Campolide              1
# 9                  Carnide              1
# 10                  Lumiar              1
# 11                 Marvila              1
# 12            Misericórdia              1
# 13  Santa Maria de Olivais              2
# 14             São Vicente              1

# %% [markdown]
# # BACHELLOR

# %%
bach = pd.read_csv('MAIN2.csv') #graduate

# %%
bach = bach.rename(columns={'Freguesia':'FREGUESIA', 'women_man':'f_Total_graduate', 
                            'man':'f_Man_graduate' ,'women': 'f_Woman_graduate'})

# %%
bach['FREGUESIA'] = [x.rstrip() for x in list(bach['FREGUESIA'])] #formating colum freguesia  ##ALALAD HAD A SPACE

# %%
#list(bach['FREGUESIA'])

# %%
bach
# Out:
#                   FREGUESIA  f_Total_graduate  f_Man_graduate  \
# 0                     Ajuda             16.45           15.42
# 1                 Alcântara             26.94           26.86
# 2                  Alvalade             42.99           45.33
# 3                   Areeiro             44.11           46.00
# 4                   Arroios             31.93           31.12
# 5            Avenidas Novas             49.30           52.62
# 6                     Beato             17.51           16.88
# 7                     Belém             47.28           49.82
# 8                   Benfica             30.02           29.28
# 9          Campo de Ourique             34.15           35.06
# 10                Campolide             25.82           24.81
# 11                  Carnide             36.48           35.70
# 12                  Estrela             39.96           42.61
# 13                   Lumiar             54.22           53.52
# ...

# %% [markdown]
# # PARK

# %%
park = pd.read_csv('parques_frequency.csv')

# %%
park = park.drop(columns = 'Unnamed: 0')

# %%
park = park.rename(columns={'Frequency':'f_Parks'})

# %%
park
# Out:
#                   FREGUESIA  f_Parks
# 0                     Ajuda        8
# 1                 Alcântara        4
# 2                  Alvalade        9
# 3                   Amadora        1
# 4                   Areeiro        9
# 5                   Arroios        8
# 6            Avenidas Novas        8
# 7                     Beato        1
# 8                     Belém       19
# 9                   Benfica        7
# 10         Campo de Ourique        4
# 11                Campolide        7
# 12                  Carnide        4
# 13                  Estrela        9
# 14                   Lumiar       13
# 15                  Marvila        8
# 16             Misericórdia        6
# 17        Parque das Nações        8
# 18              Santa Clara        4
# 19        Santa Maria Maior        3
# 20   Santa Maria de Olivais        9
# 21            Santo António        7
# 22  São Domingos de Benfica        8
# 23              São Vicente        5

# %% [markdown]
# # Police

# %%
##DONE

police = pd.read_csv('Policy_frequency.csv')
police = police.drop(columns = 'Unnamed: 0')  #Drop two NaN rows 
#police = police.rename(columns ={'Unnamed: 0': 'FREGUESIA','NOME':'f_Police_Office'})

# %%
police
# Out:
#                  FREGUESIA  f_Police_Office
# 0                Alcântara                6
# 1                 Alvalade                2
# 2                  Areeiro                2
# 3                  Arroios                4
# 4           Avenidas Novas                2
# 5                    Belém                5
# 6                  Benfica                6
# 7         Campo de Ourique                3
# 8                Campolide                3
# 9                  Carnide                5
# 10                 Estrela                8
# 11                  Lumiar                9
# 12                 Marvila                3
# 13            Misericórdia                2
# 14       Parque das Nações                3
# 15         Penha de França                4
# 16       Santa Maria Maior                8
# 17  Santa Maria de Olivais               12
# 18           Santo António                2
# 19             São Vicente                1

# %% [markdown]
# # Health

# %%
##DONE

health = pd.read_csv('saude_frequency.csv')
health = health.drop(columns = 'Unnamed: 0')
#health = health.rename(columns ={'Frequency_Saude': 'f_Health_Care_Facilities'})

# %%
#health['FREGUESIA'][2] == no_employ['FREGUESIA'][2]

# %%
#list(health['FREGUESIA'])

# %% [markdown]
# # MUSEUMS

# %%
##DONE

mus = pd.read_csv('Museus_frequency.csv')
mus = mus.drop(columns = 'Unnamed: 0')
#mus = mus[['FREGUESIA','f_Museums']]

#mus['f_Museums'].sum() should be the number of rows of our original = check

# %%
mus
# Out:
#                   FREGUESIA  f_Museums
# 0                 Alcântara          2
# 1                  Alvalade          3
# 2            Avenidas Novas          3
# 3                     Belém          9
# 4          Campo de Ourique          2
# 5                   Estrela          3
# 6                    Lumiar          2
# 7                   Marvila          1
# 8              Misericórdia          8
# 9         Parque das Nações          1
# 10          Penha de França          1
# 11        Santa Maria Maior         16
# 12            Santo António          4
# 13  São Domingos de Benfica          3
# 14              São Vicente          2

# %% [markdown]
# # UNIVERSITIES

# %%
###DONT HAVE IT!!!!

col = pd.read_csv('College_frquency.csv')
col = col.drop(columns = 'Unnamed: 0')
col
# Out:
#                   FREGUESIA  f_College
# 0                     Ajuda          3
# 1                 Alcântara          6
# 2                  Alvalade         15
# 3                   Areeiro          1
# 4                   Arroios          2
# 5            Avenidas Novas          2
# 6                   Benfica          3
# 7          Campo de Ourique          1
# 8                 Campolide          4
# 9                   Carnide          1
# 10                  Estrela          3
# 11                   Lumiar          1
# 12                  Marvila          4
# 13             Misericórdia          3
# 14        Parque das Nações          1
# 15              Santa Clara          2
# 16        Santa Maria Maior          2
# 17            Santo António          3
# 18  São Domingos de Benfica          7
# 19              São Vicente          1

# %% [markdown]
# # MERGING MERGING MERGING !

# %%
#TEST
#t = no_employ.merge(health, on= 'FREGUESIA', how = 'left')
#t

# %%
###FIRST MERGE

one = no_employ.merge(bach, on='FREGUESIA', how ='left')
one
# Out:
#                   FREGUESIA  Total_Unemployed  Man_Unemployed  \
# 0                     Ajuda             15.54           17.71
# 1                 Alcântara             11.39           12.71
# 2                  Alvalade              9.52            9.90
# 3                   Areeiro              9.58           10.81
# 4                   Arroios             12.23           13.98
# 5            Avenidas Novas              9.16            9.75
# 6                     Beato             16.57           18.42
# 7                     Belém              8.42            8.95
# 8                   Benfica             13.36           14.97
# 9          Campo de Ourique             10.73           11.61
# 10                Campolide             12.56           14.12
# 11                  Carnide             12.39           14.54
# 12                  Estrela             10.35           11.24
# 13                   Lumiar              8.01            8.56
# ...

# %%
##SECOND MERGE


two =one.merge(health, on='FREGUESIA', how ='left')
two
# Out:
#                   FREGUESIA  Total_Unemployed  Man_Unemployed  \
# 0                     Ajuda             15.54           17.71
# 1                 Alcântara             11.39           12.71
# 2                  Alvalade              9.52            9.90
# 3                   Areeiro              9.58           10.81
# 4                   Arroios             12.23           13.98
# 5            Avenidas Novas              9.16            9.75
# 6                     Beato             16.57           18.42
# 7                     Belém              8.42            8.95
# 8                   Benfica             13.36           14.97
# 9          Campo de Ourique             10.73           11.61
# 10                Campolide             12.56           14.12
# 11                  Carnide             12.39           14.54
# 12                  Estrela             10.35           11.24
# 13                   Lumiar              8.01            8.56
# ...

# %%
#THERD MERGE

three =two.merge(police, on='FREGUESIA', how ='left')
three
# Out:
#                   FREGUESIA  Total_Unemployed  Man_Unemployed  \
# 0                     Ajuda             15.54           17.71
# 1                 Alcântara             11.39           12.71
# 2                  Alvalade              9.52            9.90
# 3                   Areeiro              9.58           10.81
# 4                   Arroios             12.23           13.98
# 5            Avenidas Novas              9.16            9.75
# 6                     Beato             16.57           18.42
# 7                     Belém              8.42            8.95
# 8                   Benfica             13.36           14.97
# 9          Campo de Ourique             10.73           11.61
# 10                Campolide             12.56           14.12
# 11                  Carnide             12.39           14.54
# 12                  Estrela             10.35           11.24
# 13                   Lumiar              8.01            8.56
# ...

# %%
four =three.merge(cycl, on='FREGUESIA', how ='left')

four
# Out:
#                   FREGUESIA  Total_Unemployed  Man_Unemployed  \
# 0                     Ajuda             15.54           17.71
# 1                 Alcântara             11.39           12.71
# 2                  Alvalade              9.52            9.90
# 3                   Areeiro              9.58           10.81
# 4                   Arroios             12.23           13.98
# 5            Avenidas Novas              9.16            9.75
# 6                     Beato             16.57           18.42
# 7                     Belém              8.42            8.95
# 8                   Benfica             13.36           14.97
# 9          Campo de Ourique             10.73           11.61
# 10                Campolide             12.56           14.12
# 11                  Carnide             12.39           14.54
# 12                  Estrela             10.35           11.24
# 13                   Lumiar              8.01            8.56
# ...

# %%
five =four.merge(mus, on='FREGUESIA', how ='left')
five
# Out:
#                   FREGUESIA  Total_Unemployed  Man_Unemployed  \
# 0                     Ajuda             15.54           17.71
# 1                 Alcântara             11.39           12.71
# 2                  Alvalade              9.52            9.90
# 3                   Areeiro              9.58           10.81
# 4                   Arroios             12.23           13.98
# 5            Avenidas Novas              9.16            9.75
# 6                     Beato             16.57           18.42
# 7                     Belém              8.42            8.95
# 8                   Benfica             13.36           14.97
# 9          Campo de Ourique             10.73           11.61
# 10                Campolide             12.56           14.12
# 11                  Carnide             12.39           14.54
# 12                  Estrela             10.35           11.24
# 13                   Lumiar              8.01            8.56
# ...

# %%
six =five.merge(h_shool, on='FREGUESIA', how ='left')
six
# Out:
#                   FREGUESIA  Total_Unemployed  Man_Unemployed  \
# 0                     Ajuda             15.54           17.71
# 1                 Alcântara             11.39           12.71
# 2                  Alvalade              9.52            9.90
# 3                   Areeiro              9.58           10.81
# 4                   Arroios             12.23           13.98
# 5            Avenidas Novas              9.16            9.75
# 6                     Beato             16.57           18.42
# 7                     Belém              8.42            8.95
# 8                   Benfica             13.36           14.97
# 9          Campo de Ourique             10.73           11.61
# 10                Campolide             12.56           14.12
# 11                  Carnide             12.39           14.54
# 12                  Estrela             10.35           11.24
# 13                   Lumiar              8.01            8.56
# ...

# %%
seven =six.merge(park, on='FREGUESIA', how ='left')
seven
# Out:
#                   FREGUESIA  Total_Unemployed  Man_Unemployed  \
# 0                     Ajuda             15.54           17.71
# 1                 Alcântara             11.39           12.71
# 2                  Alvalade              9.52            9.90
# 3                   Areeiro              9.58           10.81
# 4                   Arroios             12.23           13.98
# 5            Avenidas Novas              9.16            9.75
# 6                     Beato             16.57           18.42
# 7                     Belém              8.42            8.95
# 8                   Benfica             13.36           14.97
# 9          Campo de Ourique             10.73           11.61
# 10                Campolide             12.56           14.12
# 11                  Carnide             12.39           14.54
# 12                  Estrela             10.35           11.24
# 13                   Lumiar              8.01            8.56
# ...

# %%
#OUR DATA

our_data_start = seven.merge(col, on='FREGUESIA', how = 'left')
our_data_start
# Out:
#                   FREGUESIA  Total_Unemployed  Man_Unemployed  \
# 0                     Ajuda             15.54           17.71
# 1                 Alcântara             11.39           12.71
# 2                  Alvalade              9.52            9.90
# 3                   Areeiro              9.58           10.81
# 4                   Arroios             12.23           13.98
# 5            Avenidas Novas              9.16            9.75
# 6                     Beato             16.57           18.42
# 7                     Belém              8.42            8.95
# 8                   Benfica             13.36           14.97
# 9          Campo de Ourique             10.73           11.61
# 10                Campolide             12.56           14.12
# 11                  Carnide             12.39           14.54
# 12                  Estrela             10.35           11.24
# 13                   Lumiar              8.01            8.56
# ...

# %%
##FILL NAN

our_data_start = our_data_start.fillna(0)
our_data_start
# Out:
#                   FREGUESIA  Total_Unemployed  Man_Unemployed  \
# 0                     Ajuda             15.54           17.71
# 1                 Alcântara             11.39           12.71
# 2                  Alvalade              9.52            9.90
# 3                   Areeiro              9.58           10.81
# 4                   Arroios             12.23           13.98
# 5            Avenidas Novas              9.16            9.75
# 6                     Beato             16.57           18.42
# 7                     Belém              8.42            8.95
# 8                   Benfica             13.36           14.97
# 9          Campo de Ourique             10.73           11.61
# 10                Campolide             12.56           14.12
# 11                  Carnide             12.39           14.54
# 12                  Estrela             10.35           11.24
# 13                   Lumiar              8.01            8.56
# ...

# %%
#our_data_start.to_csv('DATA_START.csv')

# %%
total1.sum() #THE QUANTITY OF ENTERIES IS REALLY LOW SO I HAD TO DROP BECAUSE THEY WOULDNT COMPLETE THE QUANTIS FOR...
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-050d0ac6ca78> in <module>
# ----> 1 total1.sum() #THE QUANTITY OF ENTERIES IS REALLY LOW SO I HAD TO DROP BECAUSE THEY WOULDNT COMPLETE THE QUANTIS FOR...
#
# NameError: name 'total1' is not defined

# %%
#cutoffs quantis

labels = ['Low', 'High']

#n = pd.qcut(our_data_start['Total_Unemployed'],5, labels=labels)
n
# Out:
# 0     Very High
# 1      Moderate
# 2           Low
# 3           Low
# 4      Moderate
# 5      Very Low
# 6     Very High
# 7      Very Low
# 8          High
# 9           Low
# 10     Moderate
# 11     Moderate
# 12          Low
# 13     Very Low
# 14    Very High
# 15         High
# 16         High
# 17     Very Low
# 18         High
# 19    Very High
# 20    Very High
# 21          Low
# 22     Very Low
# 23         High
# Name: Total_Unemployed, dtype: category
# Categories (5, object): [Very Low < Low < Moderate < High < Very High]

# %%
test2 = our_data_start.drop(columns=['FREGUESIA'])

# %%
y = lambda x :pd.qcut(x,2, labels=labels)


test2_with_binn = test2.apply(y)

# %%
 test2_with_binn
print(list(test2_with_binn['f_Museums']))
# Out:
# ['Low', 'High', 'High', 'Low', 'Low', 'High', 'Low', 'High', 'Low', 'High', 'Low', 'Low', 'High', 'High', 'Low', 'High', 'Low', 'Low', 'Low', 'Low', 'High', 'High', 'High', 'Low']

# %%
test2_with_binn.to_csv('hig_low.csv')

# %%
#DataFrame.sum(axis=None, skipna=None, level=None, numeric_only=None, min_count=0, **kwargs)
